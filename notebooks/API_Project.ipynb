# %%
import pandas as pd  
import requests
import matplotlib.pyplot as plt

# %%
endpoint = 'http://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.PP.KD?format=json'

# %%
params = {
    "start_date": "2020",
    "end_date": "2022",
    
}

# %%
response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
res = response.json()
res
# Out:
# [{'page': 1,
#   'pages': 336,
#   'per_page': 50,
#   'total': 16758,
#   'sourceid': '2',
#   'lastupdated': '2023-09-19'},
#  [{'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2022',
#    'value': 3553.91337005893,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2021',
#    'value': 3519.17483992362,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2020',
#    'value': 3455.02311899819,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2019',
#    'value': 3648.22030166291,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2018',
#    'value': 3661.36056587341,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2017',
#    'value': 3659.05909693489,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2016',
#    'value': 3654.57881507825,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2015',
#    'value': 3658.53358807156,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2014',
#    'value': 3642.87537285488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2013',
#    'value': 3593.29906466878,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2012',
#    'value': 3543.82494589859,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2011',
#    'value': 3558.37852760954,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2010',
#    'value': 3513.31591991381,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2009',
#    'value': 3431.17802938128,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2008',
#    'value': 3501.83805139738,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2007',
#    'value': 3440.84124639664,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2006',
#    'value': 3310.51500785245,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2005',
#    'value': 3185.39412330976,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2004',
#    'value': 3075.54623017324,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2003',
#    'value': 2985.91855148687,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2002',
#    'value': 2966.03980619626,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2001',
#    'value': 2928.06294631739,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2000',
#    'value': 2897.14084131096,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1999',
#    'value': 2873.553735076,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1998',
#    'value': 2867.96024335881,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1997',
#    'value': 2886.5662346724,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1996',
#    'value': 2838.69202923462,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1995',
#    'value': 2764.30501682708,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1994',
#    'value': 2715.13111572038,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1993',
#    'value': 2737.73124007534,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1992',
#    'value': 2823.94036641,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1991',
#    'value': 2955.6422383964,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1990',
#    'value': 3037.29746611811,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1989',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1988',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1987',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1986',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1985',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1984',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1983',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1982',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1981',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1980',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1979',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1978',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1977',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1976',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1975',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1974',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.PCAP.PP.KD',
#     'value': 'GDP per capita, PPP (constant 2017 international $)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1973',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %%
pd.DataFrame(response)
# Out:
#                                                      0
# 0    b'[{"page":1,"pages":336,"per_page":50,"total"...
# 1    b'P.KD","value":"GDP per capita, PPP (constant...
# 2    b',"countryiso3code":"AFE","date":"2022","valu...
# 3    b'P.PCAP.PP.KD","value":"GDP per capita, PPP (...
# 4    b'uthern"},"countryiso3code":"AFE","date":"202...
# ..                                                 ...
# 98   b'it":"","obs_status":"","decimal":0},{"indica...
# 99   b'onal $)"},"country":{"id":"ZH","value":"Afri...
# 100  b'"","obs_status":"","decimal":0},{"indicator"...
# 101  b' $)"},"country":{"id":"ZH","value":"Africa E...
# 102                   b'obs_status":"","decimal":0}]]'
#
# [103 rows x 1 columns]
